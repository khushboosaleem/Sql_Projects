# %%
import pandas as pd
import sqlite3 as sql

# %%
db = "jobs.db"
print(db)
# Out:
# jobs.db

# %%
conn = sql.connect(db)
print(conn)

# %%
# sqlite_master table, which contains metadata about the database's structure.
q = "select * from sqlite_master"
# q
pd.read_sql_query(q, conn)
# Out:
#     type                   name      tbl_name  rootpage  \
# 0  table           recent_grads  recent_grads         2
# 1  index  ix_recent_grads_index  recent_grads         3
#
#                                                  sql
# 0  CREATE TABLE "recent_grads" (\n"index" INTEGER...
# 1  CREATE INDEX "ix_recent_grads_index"ON "recent...

# %%
# read the table
q = "select * from recent_grads"
pd.read_sql_query(q, conn)
# Out:
#      index  Rank  Major_code                                      Major  \
# 0        0     1        2419                      PETROLEUM ENGINEERING
# 1        1     2        2416             MINING AND MINERAL ENGINEERING
# 2        2     3        2415                  METALLURGICAL ENGINEERING
# 3        3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4        4     5        2405                       CHEMICAL ENGINEERING
# ..     ...   ...         ...                                        ...
# 168    168   169        3609                                    ZOOLOGY
# 169    169   170        5201                     EDUCATIONAL PSYCHOLOGY
# 170    170   171        5202                        CLINICAL PSYCHOLOGY
# 171    171   172        5203                      COUNSELING PSYCHOLOGY
# 172    172   173        3501                            LIBRARY SCIENCE
#
#                Major_category  Total  Sample_size    Men  Women  ShareWomen  \
# ...

# %%
q = "select * from recent_grads"
df = pd.read_sql_query(q, conn)
df
# Out:
#      index  Rank  Major_code                                      Major  \
# 0        0     1        2419                      PETROLEUM ENGINEERING
# 1        1     2        2416             MINING AND MINERAL ENGINEERING
# 2        2     3        2415                  METALLURGICAL ENGINEERING
# 3        3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4        4     5        2405                       CHEMICAL ENGINEERING
# ..     ...   ...         ...                                        ...
# 168    168   169        3609                                    ZOOLOGY
# 169    169   170        5201                     EDUCATIONAL PSYCHOLOGY
# 170    170   171        5202                        CLINICAL PSYCHOLOGY
# 171    171   172        5203                      COUNSELING PSYCHOLOGY
# 172    172   173        3501                            LIBRARY SCIENCE
#
#                Major_category  Total  Sample_size    Men  Women  ShareWomen  \
# ...

# %%
df[df["Major_category"] == "Engineering"]
# Out:
#     index  Rank  Major_code                                        Major  \
# 0       0     1        2419                        PETROLEUM ENGINEERING
# 1       1     2        2416               MINING AND MINERAL ENGINEERING
# 2       2     3        2415                    METALLURGICAL ENGINEERING
# 3       3     4        2417    NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       4     5        2405                         CHEMICAL ENGINEERING
# 5       5     6        2418                          NUCLEAR ENGINEERING
# 8       8     9        2414                       MECHANICAL ENGINEERING
# 9       9    10        2408                       ELECTRICAL ENGINEERING
# 10     10    11        2407                         COMPUTER ENGINEERING
# 11     11    12        2401                        AEROSPACE ENGINEERING
# 12     12    13        2404                       BIOMEDICAL ENGINEERING
# 13     13    14        5008                            MATERIALS SCIENCE
# ...

# %%
# file write to csv 
q = "select * from recent_grads"
df = pd.read_sql_query(q, conn)
# df.to_csv('recent_grade2.csv')

# %%
q = "select ShareWomen from recent_grads"
pd.read_sql_query(q , conn)
# Out:
#      ShareWomen
# 0      0.120564
# 1      0.101852
# 2      0.153037
# 3      0.107313
# 4      0.341631
# ..          ...
# 168    0.637293
# 169    0.817099
# 170    0.799859
# 171    0.798746
# 172    0.877960
#
# [173 rows x 1 columns]

# %%
df['ShareWomen']
# Out:
# 0      0.120564
# 1      0.101852
# 2      0.153037
# 3      0.107313
# 4      0.341631
#          ...
# 168    0.637293
# 169    0.817099
# 170    0.799859
# 171    0.798746
# 172    0.877960
# Name: ShareWomen, Length: 173, dtype: float64

# %%
for i in df['ShareWomen']:
    print(i)
# Out:
# 0.120564344
# 0.10185185199999999
# 0.153037383
# 0.107313196
# 0.341630502
# 0.144966965
# 0.535714286
# 0.44135557299999995
# 0.139792801
# 0.437846874
# 0.199412643
# 0.19645025600000002
# 0.11955890300000001
# 0.310820285
# 0.183985189
# 0.32078431399999996
# 0.34347321799999997
# 0.252959838
# 0.35044247799999995
# 0.236062718
# 0.578766338
# 0.222695002
# 0.325091881
# 0.292607004
# 0.278790146
# 0.22711794300000002
# 0.342228811
# 0.322222222
# 0.189970437
# 0.251388889
# 0.558548009
# 0.09071250900000001
# 0.41017964100000004
# 0.32483805
# 0.896018988
# 0.355469059
# 0.34082495700000004
# 0.24919024
# 0.75047259
# 0.430536761
# 0.253583302
# 0.24410308100000003
# 0.7077185020000001
# 0.448098678
# 0.43429844100000004
# 0.526475764
# 0.281936407
# 0.75392736
# 0.524152583
# 0.688999173
# 0.174122505
# 0.178981938
# 0.927807246
# 0.269193858
# 0.854523227
# 0.56486557
# 0.632986838
# 0.4179248
# 0.321769663
# 0.28290282899999997
# 0.451464886
# 0.07745302700000001
# ...

# %%
df['ShareWomen'].max()
# Out:
# 0.968953683

# %%
df['ShareWomen'].min()
# Out:
# 0.0

# %%
# check just starting 10 
q = "select ShareWomen from recent_grads limit 10"
pd.read_sql_query(q , conn)
# Out:
#    ShareWomen
# 0    0.120564
# 1    0.101852
# 2    0.153037
# 3    0.107313
# 4    0.341631
# 5    0.144967
# 6    0.535714
# 7    0.441356
# 8    0.139793
# 9    0.437847

# %%
# check just starting 20 
q = "select ShareWomen from recent_grads limit 20"
pd.read_sql_query(q , conn)
# Out:
#     ShareWomen
# 0     0.120564
# 1     0.101852
# 2     0.153037
# 3     0.107313
# 4     0.341631
# 5     0.144967
# 6     0.535714
# 7     0.441356
# 8     0.139793
# 9     0.437847
# 10    0.199413
# 11    0.196450
# 12    0.119559
# 13    0.310820
# 14    0.183985
# 15    0.320784
# 16    0.343473
# 17    0.252960
# 18    0.350442
# 19    0.236063

# %%
# Check two col with limit
q = "select ShareWomen, Major from recent_grads limit 10"
pd.read_sql_query(q, conn)
# Out:
#    ShareWomen                                      Major
# 0    0.120564                      PETROLEUM ENGINEERING
# 1    0.101852             MINING AND MINERAL ENGINEERING
# 2    0.153037                  METALLURGICAL ENGINEERING
# 3    0.107313  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4    0.341631                       CHEMICAL ENGINEERING
# 5    0.144967                        NUCLEAR ENGINEERING
# 6    0.535714                          ACTUARIAL SCIENCE
# 7    0.441356                 ASTRONOMY AND ASTROPHYSICS
# 8    0.139793                     MECHANICAL ENGINEERING
# 9    0.437847                     ELECTRICAL ENGINEERING

# %%
# Check three col with limit
q = "select ShareWomen, Major, Women from recent_grads limit 10"
pd.read_sql_query(q, conn)
# Out:
#    ShareWomen                                      Major  Women
# 0    0.120564                      PETROLEUM ENGINEERING    282
# 1    0.101852             MINING AND MINERAL ENGINEERING     77
# 2    0.153037                  METALLURGICAL ENGINEERING    131
# 3    0.107313  NAVAL ARCHITECTURE AND MARINE ENGINEERING    135
# 4    0.341631                       CHEMICAL ENGINEERING  11021
# 5    0.144967                        NUCLEAR ENGINEERING    373
# 6    0.535714                          ACTUARIAL SCIENCE    960
# 7    0.441356                 ASTRONOMY AND ASTROPHYSICS   1667
# 8    0.139793                     MECHANICAL ENGINEERING   2105
# 9    0.437847                     ELECTRICAL ENGINEERING   6548

# %%
# make a condition Check ShareWomen >0.5 and ShareWomen < 0.8
q = "select ShareWomen, Major from recent_grads where ShareWomen > 0.5 and ShareWomen < 0.8 "
pd.read_sql_query(q, conn)
# Out:
#     ShareWomen                               Major
# 0     0.535714                   ACTUARIAL SCIENCE
# 1     0.578766                    COMPUTER SCIENCE
# 2     0.558548           ENVIRONMENTAL ENGINEERING
# 3     0.750473  INDUSTRIAL PRODUCTION TECHNOLOGIES
# 4     0.707719    COMPUTER AND INFORMATION SYSTEMS
# ..         ...                                 ...
# 74    0.629505              DRAMA AND THEATER ARTS
# 75    0.666119            COMPOSITION AND RHETORIC
# 76    0.637293                             ZOOLOGY
# 77    0.799859                 CLINICAL PSYCHOLOGY
# 78    0.798746               COUNSELING PSYCHOLOGY
#
# [79 rows x 2 columns]

# %%
df[(df["ShareWomen"] > 0.5) & (df["ShareWomen"] < 0.8)]
# Out:
#      index  Rank  Major_code                               Major  \
# 6        6     7        6202                   ACTUARIAL SCIENCE
# 20      20    21        2102                    COMPUTER SCIENCE
# 30      30    31        2410           ENVIRONMENTAL ENGINEERING
# 38      38    39        2503  INDUSTRIAL PRODUCTION TECHNOLOGIES
# 42      42    43        2100    COMPUTER AND INFORMATION SYSTEMS
# ..     ...   ...         ...                                 ...
# 166    166   167        6001              DRAMA AND THEATER ARTS
# 167    167   168        3302            COMPOSITION AND RHETORIC
# 168    168   169        3609                             ZOOLOGY
# 170    170   171        5202                 CLINICAL PSYCHOLOGY
# 171    171   172        5203               COUNSELING PSYCHOLOGY
#
#                 Major_category   Total  Sample_size    Men  Women  ShareWomen  \
# 6                     Business    3777           51    832    960    0.535714
# ...

# %%
# Check starting five rows by using head
q = "select shareWomen, Major from recent_grads"
df_sel = pd.read_sql_query(q, conn)
df_sel.head()
# Out:
#    ShareWomen                                      Major
# 0    0.120564                      PETROLEUM ENGINEERING
# 1    0.101852             MINING AND MINERAL ENGINEERING
# 2    0.153037                  METALLURGICAL ENGINEERING
# 3    0.107313  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4    0.341631                       CHEMICAL ENGINEERING

# %%
# Another way to Check starting five rows by using sql query limit
q = "select shareWomen, Major from recent_grads limit 6"
pd.read_sql_query(q,conn)
# Out:
#    ShareWomen                                      Major
# 0    0.120564                      PETROLEUM ENGINEERING
# 1    0.101852             MINING AND MINERAL ENGINEERING
# 2    0.153037                  METALLURGICAL ENGINEERING
# 3    0.107313  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4    0.341631                       CHEMICAL ENGINEERING
# 5    0.144967                        NUCLEAR ENGINEERING

# %%
q = """select ShareWomen, Major, Major_category
        from recent_grads 
        where ShareWomen > 0.5 or (Major_category == 'Engineering' and ShareWomen <= 0.5)

"""
pd.read_sql_query(q, conn)
# Out:
#      ShareWomen                                      Major  \
# 0      0.120564                      PETROLEUM ENGINEERING
# 1      0.101852             MINING AND MINERAL ENGINEERING
# 2      0.153037                  METALLURGICAL ENGINEERING
# 3      0.107313  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4      0.341631                       CHEMICAL ENGINEERING
# ..          ...                                        ...
# 119    0.637293                                    ZOOLOGY
# 120    0.817099                     EDUCATIONAL PSYCHOLOGY
# 121    0.799859                        CLINICAL PSYCHOLOGY
# 122    0.798746                      COUNSELING PSYCHOLOGY
# 123    0.877960                            LIBRARY SCIENCE
#
#                Major_category
# 0                 Engineering
# 1                 Engineering
# 2                 Engineering
# 3                 Engineering
# 4                 Engineering
# ..                        ...
# 119    Biology & Life Science
# ...

# %%
df
# Out:
#      index  Rank  Major_code                                      Major  \
# 0        0     1        2419                      PETROLEUM ENGINEERING
# 1        1     2        2416             MINING AND MINERAL ENGINEERING
# 2        2     3        2415                  METALLURGICAL ENGINEERING
# 3        3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4        4     5        2405                       CHEMICAL ENGINEERING
# ..     ...   ...         ...                                        ...
# 168    168   169        3609                                    ZOOLOGY
# 169    169   170        5201                     EDUCATIONAL PSYCHOLOGY
# 170    170   171        5202                        CLINICAL PSYCHOLOGY
# 171    171   172        5203                      COUNSELING PSYCHOLOGY
# 172    172   173        3501                            LIBRARY SCIENCE
#
#                Major_category  Total  Sample_size    Men  Women  ShareWomen  \
# ...

# %%
df[df["ShareWomen"] > 0.5]
# Out:
#      index  Rank  Major_code                               Major  \
# 6        6     7        6202                   ACTUARIAL SCIENCE
# 20      20    21        2102                    COMPUTER SCIENCE
# 30      30    31        2410           ENVIRONMENTAL ENGINEERING
# 34      34    35        6107                             NURSING
# 38      38    39        2503  INDUSTRIAL PRODUCTION TECHNOLOGIES
# ..     ...   ...         ...                                 ...
# 168    168   169        3609                             ZOOLOGY
# 169    169   170        5201              EDUCATIONAL PSYCHOLOGY
# 170    170   171        5202                 CLINICAL PSYCHOLOGY
# 171    171   172        5203               COUNSELING PSYCHOLOGY
# 172    172   173        3501                     LIBRARY SCIENCE
#
#                Major_category   Total  Sample_size    Men   Women  ShareWomen  \
# 6                    Business    3777           51    832     960    0.535714
# ...

# %%
df1 = df [["ShareWomen","Major_category"]]
df1
# Out:
#      ShareWomen            Major_category
# 0      0.120564               Engineering
# 1      0.101852               Engineering
# 2      0.153037               Engineering
# 3      0.107313               Engineering
# 4      0.341631               Engineering
# ..          ...                       ...
# 168    0.637293    Biology & Life Science
# 169    0.817099  Psychology & Social Work
# 170    0.799859  Psychology & Social Work
# 171    0.798746  Psychology & Social Work
# 172    0.877960                 Education
#
# [173 rows x 2 columns]

# %%
df1[(df1["ShareWomen"] > 0.5) | ((df1["Major_category"] == "Engineering" ) & (df1["ShareWomen"] <= 0.5))]
# Out:
#      ShareWomen            Major_category
# 0      0.120564               Engineering
# 1      0.101852               Engineering
# 2      0.153037               Engineering
# 3      0.107313               Engineering
# 4      0.341631               Engineering
# ..          ...                       ...
# 168    0.637293    Biology & Life Science
# 169    0.817099  Psychology & Social Work
# 170    0.799859  Psychology & Social Work
# 171    0.798746  Psychology & Social Work
# 172    0.877960                 Education
#
# [124 rows x 2 columns]

# %%
q = """select ShareWomen, Major, Major_category 
        from recent_grads 
        where ShareWomen > 0.5 or (Major_category == 'Engineering' and ShareWomen <= 0.5) 
        order by ShareWomen ASC limit 10"""

pd.read_sql_query(q, conn)
# Out:
#    ShareWomen                                      Major Major_category
# 0    0.000000     MISCELLANEOUS ENGINEERING TECHNOLOGIES    Engineering
# 1    0.090713                   ENGINEERING TECHNOLOGIES    Engineering
# 2    0.101852             MINING AND MINERAL ENGINEERING    Engineering
# 3    0.107313  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4    0.119559                     BIOMEDICAL ENGINEERING    Engineering
# 5    0.120564                      PETROLEUM ENGINEERING    Engineering
# 6    0.139793                     MECHANICAL ENGINEERING    Engineering
# 7    0.144967                        NUCLEAR ENGINEERING    Engineering
# 8    0.153037                  METALLURGICAL ENGINEERING    Engineering
# 9    0.174123      ENGINEERING AND INDUSTRIAL MANAGEMENT    Engineering

# %%
q = """select ShareWomen, Major, Major_category 
        from recent_grads 
        where ShareWomen > 0.5 or (Major_category == 'Engineering' and ShareWomen <= 0.5) 
        order by ShareWomen DESC limit 10"""

pd.read_sql_query(q, conn)
# Out:
#    ShareWomen                                      Major  \
# 0    0.968954                ANTHROPOLOGY AND ARCHEOLOGY
# 1    0.967998                  EARLY CHILDHOOD EDUCATION
# 2    0.927807           MATHEMATICS AND COMPUTER SCIENCE
# 3    0.923745                       ELEMENTARY EDUCATION
# 4    0.910933                            ANIMAL SCIENCES
# 5    0.906677                                 PHYSIOLOGY
# 6    0.905590                   MISCELLANEOUS PSYCHOLOGY
# 7    0.904075  HUMAN SERVICES AND COMMUNITY ORGANIZATION
# 8    0.896019                                    NURSING
# 9    0.881294                                GEOSCIENCES
#
#                     Major_category
# 0        Humanities & Liberal Arts
# 1                        Education
# 2          Computers & Mathematics
# 3                        Education
# 4  Agriculture & Natural Resources
# 5           Biology & Life Science
# 6         Psychology & Social Work
# 7         Psychology & Social Work
# ...

# %%
# by using query
q = """select count(ShareWomen)
        from recent_grads
    """
pd.read_sql_query(q,conn)
# Out:
#    count(ShareWomen)
# 0                173

# %%
# by using pandas
df["ShareWomen"].count()
# Out:
# 173

# %%
# the len of this col is 173
df["ShareWomen"]
# Out:
# 0      0.120564
# 1      0.101852
# 2      0.153037
# 3      0.107313
# 4      0.341631
#          ...
# 168    0.637293
# 169    0.817099
# 170    0.799859
# 171    0.798746
# 172    0.877960
# Name: ShareWomen, Length: 173, dtype: float64

# %%
q = """select count(ShareWomen) 
        from recent_grads
        where ShareWomen > 0.5 or (Major_category == 'Engineering' and ShareWomen <= 0.5)
"""
pd.read_sql_query(q, conn)
# Out:
#    count(ShareWomen)
# 0                124

# %%
q = """select count(ShareWomen) 
        from recent_grads
        where ShareWomen > 0.5 and Major_category == 'Engineering'
"""
pd.read_sql_query(q, conn)
# Out:
#    count(ShareWomen)
# 0                  2

# %%
q = """select ShareWomen, Major
        from recent_grads
        where ShareWomen > 0.5 or (Major_category == 'Engineering' and ShareWomen <= 0.5)
"""
pd.read_sql_query(q, conn)
# Out:
#      ShareWomen                                      Major
# 0      0.120564                      PETROLEUM ENGINEERING
# 1      0.101852             MINING AND MINERAL ENGINEERING
# 2      0.153037                  METALLURGICAL ENGINEERING
# 3      0.107313  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4      0.341631                       CHEMICAL ENGINEERING
# ..          ...                                        ...
# 119    0.637293                                    ZOOLOGY
# 120    0.817099                     EDUCATIONAL PSYCHOLOGY
# 121    0.799859                        CLINICAL PSYCHOLOGY
# 122    0.798746                      COUNSELING PSYCHOLOGY
# 123    0.877960                            LIBRARY SCIENCE
#
# [124 rows x 2 columns]

# %%
q = """select ShareWomen, Major, Major_category
        from recent_grads
        where ShareWomen > 0.5 and Major_category == 'Engineering' 
"""
pd.read_sql_query(q, conn)
# Out:
#    ShareWomen                               Major Major_category
# 0    0.558548           ENVIRONMENTAL ENGINEERING    Engineering
# 1    0.750473  INDUSTRIAL PRODUCTION TECHNOLOGIES    Engineering

# %%
df
# Out:
#      index  Rank  Major_code                                      Major  \
# 0        0     1        2419                      PETROLEUM ENGINEERING
# 1        1     2        2416             MINING AND MINERAL ENGINEERING
# 2        2     3        2415                  METALLURGICAL ENGINEERING
# 3        3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4        4     5        2405                       CHEMICAL ENGINEERING
# ..     ...   ...         ...                                        ...
# 168    168   169        3609                                    ZOOLOGY
# 169    169   170        5201                     EDUCATIONAL PSYCHOLOGY
# 170    170   171        5202                        CLINICAL PSYCHOLOGY
# 171    171   172        5203                      COUNSELING PSYCHOLOGY
# 172    172   173        3501                            LIBRARY SCIENCE
#
#                Major_category  Total  Sample_size    Men  Women  ShareWomen  \
# ...

# %%
# Add the column name
q = """select count(Major_category) "No of Engineering Field"
        from recent_grads 
        where Major_category == 'Engineering'       
"""
pd.read_sql_query(q, conn)
# Out:
#    No of Engineering Field
# 0                       29

# %%
# Check count of (Major count) 
q = """select count(Major_category) 
        from recent_grads
"""
pd.read_sql_query(q, conn)
# Out:
#    count(Major_category)
# 0                    173

# %%
# Check count of (Major count) and change column name
q = """select count(Major_category) "No of Engineering Field"
        from recent_grads
"""
pd.read_sql_query(q, conn)
# Out:
#    No of Engineering Field
# 0                      173

# %%
# Check count of (Major count) and change column name
q = """select count(Major_category) "No of Engineering Field"
        from recent_grads
"""
pd.read_sql_query(q, conn)
# Out:
#    No of Engineering Field
# 0                      173

# %%
df
# Out:
#      index  Rank  Major_code                                      Major  \
# 0        0     1        2419                      PETROLEUM ENGINEERING
# 1        1     2        2416             MINING AND MINERAL ENGINEERING
# 2        2     3        2415                  METALLURGICAL ENGINEERING
# 3        3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4        4     5        2405                       CHEMICAL ENGINEERING
# ..     ...   ...         ...                                        ...
# 168    168   169        3609                                    ZOOLOGY
# 169    169   170        5201                     EDUCATIONAL PSYCHOLOGY
# 170    170   171        5202                        CLINICAL PSYCHOLOGY
# 171    171   172        5203                      COUNSELING PSYCHOLOGY
# 172    172   173        3501                            LIBRARY SCIENCE
#
#                Major_category  Total  Sample_size    Men  Women  ShareWomen  \
# ...

# %%
# Check count of (Major count) and change column name and find sum of Total column 
q = """select count(Major_category) "No of Engineering Field",
        sum(Total)
        from recent_grads
"""
pd.read_sql_query(q, conn)
# Out:
#    No of Engineering Field  sum(Total)
# 0                      173     6776015

# %%
# Check count of (Major count) and change column name and find sum of Total column 
q = """select count(Major_category) "No of Engineering Field",
        sum(Total) "No of Passout Engineering Field"
        from recent_grads
        Where Major_category == 'Engineering'
"""
pd.read_sql_query(q, conn)
# Out:
#    No of Engineering Field  No of Passout Engineering Field
# 0                       29                           537583

# %%
# Check count of (Major count) and change column name and find sum of Total column and check no of Passout Engineering Field 
q = """select count(Major_category) "No of Engineering Field",
        sum(Total) "No of Passout Engineering Field"
        from recent_grads
        Where Major_category == 'Engineering'
"""
pd.read_sql_query(q, conn)
# Out:
#    No of Engineering Field  No of Passout Engineering Field
# 0                       29                           537583

# %%
# Make a function for sql query 
def sql_query(q):
    return pd.read_sql_query(q, conn)

# %%
# Check count of all col
q = """select count(*) from recent_grads
"""
sql_query(q)
# Out:
#    count(*)
# 0       173

# %%
# Count all col where ShareWome is greater than 0.5
q = """select count(*) from recent_grads
        where ShareWomen > 0.5
"""
sql_query(q)
# Out:
#    count(*)
# 0        97

# %%
# Count all col where ShareWome is greater than 0.5 and Major Category equal to Engineering
q = """select count(*) from recent_grads
        where ShareWomen > 0.5 and Major_category == 'Engineering'
"""
sql_query(q)
# Out:
#    count(*)
# 0         2

# %%
# Major Category is greator than 0.5
q = """select Major_category
        from recent_grads
        where ShareWomen > 0.5

"""
sql_query(q)
# Out:
#               Major_category
# 0                   Business
# 1    Computers & Mathematics
# 2                Engineering
# 3                     Health
# 4                Engineering
# ..                       ...
# 92    Biology & Life Science
# 93  Psychology & Social Work
# 94  Psychology & Social Work
# 95  Psychology & Social Work
# 96                 Education
#
# [97 rows x 1 columns]

# %%
# Unique Major_category by using pd
df["Major_category"].nunique()
# Out:
# 16

# %%
unique_check = df["Major_category"]
unique_check
# Out:
# 0                   Engineering
# 1                   Engineering
# 2                   Engineering
# 3                   Engineering
# 4                   Engineering
#                  ...
# 168      Biology & Life Science
# 169    Psychology & Social Work
# 170    Psychology & Social Work
# 171    Psychology & Social Work
# 172                   Education
# Name: Major_category, Length: 173, dtype: object

# %%
len(unique_check.unique())
# Out:
# 16

# %%
unique_check.count()
# Out:
# 173

# %%
# unique category by sql
q = """select Distinct(Major_category)
        from recent_grads 
"""
sql_query(q)
# Out:
#                          Major_category
# 0                           Engineering
# 1                              Business
# 2                     Physical Sciences
# 3                   Law & Public Policy
# 4               Computers & Mathematics
# 5       Agriculture & Natural Resources
# 6   Industrial Arts & Consumer Services
# 7                                  Arts
# 8                                Health
# 9                        Social Science
# 10               Biology & Life Science
# 11                            Education
# 12            Humanities & Liberal Arts
# 13             Psychology & Social Work
# 14          Communications & Journalism
# 15                    Interdisciplinary

# %%
# unique category by sql where ShareWomen is greator than 0.5
q = """select Distinct(Major_category)
        from recent_grads 
        where ShareWomen > 0.5
"""
sql_query(q)
# Out:
#                          Major_category
# 0                              Business
# 1               Computers & Mathematics
# 2                           Engineering
# 3                                Health
# 4                Biology & Life Science
# 5                     Physical Sciences
# 6                             Education
# 7                        Social Science
# 8       Agriculture & Natural Resources
# 9             Humanities & Liberal Arts
# 10                  Law & Public Policy
# 11             Psychology & Social Work
# 12          Communications & Journalism
# 13  Industrial Arts & Consumer Services
# 14                                 Arts

# %%
df["Major_category"].unique
# Out:
# <bound method Series.unique of 0                   Engineering
# 1                   Engineering
# 2                   Engineering
# 3                   Engineering
# 4                   Engineering
#                  ...
# 168      Biology & Life Science
# 169    Psychology & Social Work
# 170    Psychology & Social Work
# 171    Psychology & Social Work
# 172                   Education
# Name: Major_category, Length: 173, dtype: object>

# %%
SW_g = df[df["ShareWomen"] > 0.5]["Major_category"].unique
print(SW_g)
# Out:
# <bound method Series.unique of 6                      Business
# 20      Computers & Mathematics
# 30                  Engineering
# 34                       Health
# 38                  Engineering
#                  ...
# 168      Biology & Life Science
# 169    Psychology & Social Work
# 170    Psychology & Social Work
# 171    Psychology & Social Work
# 172                   Education
# Name: Major_category, Length: 97, dtype: object>

# %%
# Check lenght by using pd
len(df[df["ShareWomen"] > 0.5]["Major_category"].unique())
# Out:
# 15

# %%
# Check len by using sql
q = """select count(Distinct(Major_category)) "No of Major Category"
        from recent_grads
        where ShareWomen > 0.5

"""
sql_query(q)
# Out:
#    No of Major Category
# 0                    15

# %%
q = """select Major_category, ShareWomen
        from recent_grads limit 5

"""
sql_query(q)
# Out:
#   Major_category  ShareWomen
# 0    Engineering    0.120564
# 1    Engineering    0.101852
# 2    Engineering    0.153037
# 3    Engineering    0.107313
# 4    Engineering    0.341631

# %%
q = """select Major_category, ShareWomen
        from recent_grads

"""
sql_query(q)
# Out:
#                Major_category  ShareWomen
# 0                 Engineering    0.120564
# 1                 Engineering    0.101852
# 2                 Engineering    0.153037
# 3                 Engineering    0.107313
# 4                 Engineering    0.341631
# ..                        ...         ...
# 168    Biology & Life Science    0.637293
# 169  Psychology & Social Work    0.817099
# 170  Psychology & Social Work    0.799859
# 171  Psychology & Social Work    0.798746
# 172                 Education    0.877960
#
# [173 rows x 2 columns]

# %%
q = """select Major_category,
        avg(ShareWomen) "ShareWomen's Average"
        from recent_grads

"""
sql_query(q)
# Out:
#   Major_category  ShareWomen's Average
# 0    Engineering               0.52255

# %%
# Major_category group by where shareWomen is greator than 0.5

q = """ select Major_category, 
        avg(ShareWomen) 'Average by Category'
        from recent_grads
        where ShareWomen > 0.5
        group by Major_category


"""
sql_query(q)
# Out:
#                          Major_category  Average by Category
# 0       Agriculture & Natural Resources             0.661854
# 1                                  Arts             0.653138
# 2                Biology & Life Science             0.635900
# 3                              Business             0.630704
# 4           Communications & Journalism             0.756743
# 5               Computers & Mathematics             0.726525
# 6                             Education             0.735512
# 7                           Engineering             0.654510
# 8                                Health             0.704170
# 9             Humanities & Liberal Arts             0.722032
# 10  Industrial Arts & Consumer Services             0.718043
# 11                  Law & Public Policy             0.591001
# 12                    Physical Sciences             0.686358
# 13             Psychology & Social Work             0.820446
# ...

# %%
q = """select Major_category, avg(ShareWomen) 'Average by Category'
    from recent_grads
    group by Major_category
    
"""
sql_query(q)
# Out:
#                          Major_category  Average by Category
# 0       Agriculture & Natural Resources             0.617938
# 1                                  Arts             0.561851
# 2                Biology & Life Science             0.584518
# 3                              Business             0.405063
# 4           Communications & Journalism             0.643835
# 5               Computers & Mathematics             0.512752
# 6                             Education             0.674986
# 7                           Engineering             0.257158
# 8                                Health             0.616857
# 9             Humanities & Liberal Arts             0.676193
# 10  Industrial Arts & Consumer Services             0.449351
# 11                    Interdisciplinary             0.495397
# 12                  Law & Public Policy             0.335990
# 13                    Physical Sciences             0.508749
# ...

# %%
q = """select Major_category, avg(ShareWomen) 'Average by Category'
    from recent_grads
    group by Major_category
    having avg(ShareWomen) > 0.5
"""
sql_query(q)
# Out:
#                      Major_category  Average by Category
# 0   Agriculture & Natural Resources             0.617938
# 1                              Arts             0.561851
# 2            Biology & Life Science             0.584518
# 3       Communications & Journalism             0.643835
# 4           Computers & Mathematics             0.512752
# 5                         Education             0.674986
# 6                            Health             0.616857
# 7         Humanities & Liberal Arts             0.676193
# 8                 Physical Sciences             0.508749
# 9          Psychology & Social Work             0.777763
# 10                   Social Science             0.539067

# %%
q = """select Major_category, avg(ShareWomen) 'Average by Category'
    from recent_grads
    group by Major_category
    having avg(ShareWomen) > 0.6
"""
sql_query(q)
# Out:
#                     Major_category  Average by Category
# 0  Agriculture & Natural Resources             0.617938
# 1      Communications & Journalism             0.643835
# 2                        Education             0.674986
# 3                           Health             0.616857
# 4        Humanities & Liberal Arts             0.676193
# 5         Psychology & Social Work             0.777763

# %%
q = """select Major_category, avg(ShareWomen) Averages_by_Category
    from recent_grads 
    group by Major_category
    having Averages_by_Category > 0.6 """

sql_query(q)
# Out:
#                     Major_category  Averages_by_Category
# 0  Agriculture & Natural Resources              0.617938
# 1      Communications & Journalism              0.643835
# 2                        Education              0.674986
# 3                           Health              0.616857
# 4        Humanities & Liberal Arts              0.676193
# 5         Psychology & Social Work              0.777763

# %%
q = """select Major_category, avg(ShareWomen) Average_by_Category,
        max(ShareWomen) Max_by_Category
        from recent_grads

"""
sql_query(q)
# Out:
#               Major_category  Average_by_Category  Max_by_Category
# 0  Humanities & Liberal Arts              0.52255         0.968954

# %%
q = """select Major_category, avg(ShareWomen) Average_by_Category,
        max(ShareWomen) Max_by_Category
        from recent_grads
        group by Major_category

"""
sql_query(q)
# Out:
#                          Major_category  Average_by_Category  Max_by_Category
# 0       Agriculture & Natural Resources             0.617938         0.910933
# 1                                  Arts             0.561851         0.697384
# 2                Biology & Life Science             0.584518         0.906677
# 3                              Business             0.405063         0.733992
# 4           Communications & Journalism             0.643835         0.877228
# 5               Computers & Mathematics             0.512752         0.927807
# 6                             Education             0.674986         0.967998
# 7                           Engineering             0.257158         0.750473
# 8                                Health             0.616857         0.896019
# 9             Humanities & Liberal Arts             0.676193         0.968954
# 10  Industrial Arts & Consumer Services             0.449351         0.752144
# ...

# %%
q = """select Major_category, avg(ShareWomen) Average_by_Category,
        max(ShareWomen) Max_by_Category
        from recent_grads
        group by Major_category
        having Average_by_Category > 0.6

"""
sql_query(q)
# Out:
#                     Major_category  Average_by_Category  Max_by_Category
# 0  Agriculture & Natural Resources             0.617938         0.910933
# 1      Communications & Journalism             0.643835         0.877228
# 2                        Education             0.674986         0.967998
# 3                           Health             0.616857         0.896019
# 4        Humanities & Liberal Arts             0.676193         0.968954
# 5         Psychology & Social Work             0.777763         0.905590

# %%
q = """SELECT ShareWomen from recent_grads
"""
sql_query(q)
# Out:
#      ShareWomen
# 0      0.120564
# 1      0.101852
# 2      0.153037
# 3      0.107313
# 4      0.341631
# ..          ...
# 168    0.637293
# 169    0.817099
# 170    0.799859
# 171    0.798746
# 172    0.877960
#
# [173 rows x 1 columns]

# %%
q = """SELECT Women, Men, Total from recent_grads """
sql_query(q)
# Out:
#      Women    Men  Total
# 0      282   2057   2339
# 1       77    679    756
# 2      131    725    856
# 3      135   1123   1258
# 4    11021  21239  32260
# ..     ...    ...    ...
# 168   5359   3050   8409
# 169   2332    522   2854
# 170   2270    568   2838
# 171   3695    931   4626
# 172    964    134   1098
#
# [173 rows x 3 columns]

# %%
q = """SELECT Women/Total from recent_grads

"""
sql_query(q)
# Out:
#      Women/Total
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# 168            0
# 169            0
# 170            0
# 171            0
# 172            0
#
# [173 rows x 1 columns]

# %%
q = """SELECT (Women/Total)*100 from recent_grads

"""
sql_query(q)
# Out:
#      (Women/Total)*100
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ..                 ...
# 168                  0
# 169                  0
# 170                  0
# 171                  0
# 172                  0
#
# [173 rows x 1 columns]

# %%
(282/2339)*100
# Out:
# 12.056434373663958

# %%
int(282/2339)*100
# Out:
# 0

# %%
# Change women col data type into float
q = """Select cast(Women as float), Total from recent_grads

"""
sql_query(q)
# Out:
#      cast(Women as float)  Total
# 0                   282.0   2339
# 1                    77.0    756
# 2                   131.0    856
# 3                   135.0   1258
# 4                 11021.0  32260
# ..                    ...    ...
# 168                5359.0   8409
# 169                2332.0   2854
# 170                2270.0   2838
# 171                3695.0   4626
# 172                 964.0   1098
#
# [173 rows x 2 columns]

# %%
q = """Select Major, (cast(Women as float)/Total)*100 Percentage_Women from recent_grads
        order by Percentage_Women DESC limit 3

"""
sql_query(q)
# Out:
#                                         Major  Percentage_Women
# 0  EDUCATIONAL ADMINISTRATION AND SUPERVISION       7922.636816
# 1                                PHARMACOLOGY       5908.853575
# 2    INDUSTRIAL AND ORGANIZATIONAL PSYCHOLOGY       3395.885866

# %%
q = """Select Major,(cast(Women as float)/Total)*100 Percentage_Women from recent_grads
        order by Percentage_Women ASC limit 3

"""
sql_query(q)
# Out:
#                                     Major  Percentage_Women
# 0  MISCELLANEOUS ENGINEERING TECHNOLOGIES          0.000000
# 1                          COMMUNICATIONS          0.097665
# 2    CRIMINAL JUSTICE AND FIRE PROTECTION          0.295111

# %%
q = """Select Major, (Cast(Women as float)/Total)*100 Percentage_Women from recent_grads
        where Percentage_Women > 100 

"""
sql_query(q)
# Out:
#                                                 Major  Percentage_Women
# 0                               AEROSPACE ENGINEERING        106.362067
# 1                                        FOOD SCIENCE        655.262554
# 2         MATERIALS ENGINEERING AND MATERIALS SCIENCE        113.063816
# 3              GEOLOGICAL AND GEOPHYSICAL ENGINEERING        529.305556
# 4   NUCLEAR, INDUSTRIAL RADIOLOGY, AND BIOLOGICAL ...        270.652174
# 5                                             PHYSICS        100.930247
# 6                     STATISTICS AND DECISION SCIENCE        144.968805
# 7                                 APPLIED MATHEMATICS        242.923669
# 8                                        PHARMACOLOGY       5908.853575
# 9                    MATHEMATICS AND COMPUTER SCIENCE       1694.581281
# 10                          SCHOOL STUDENT COUNSELING        264.547677
# 11                              UNITED STATES HISTORY        482.429360
# ...

# %%
q = """Select Major, (Cast(Women as float)/Total)*100 Percentage_Women from recent_grads
        where Percentage_Women > 100 limit 5

"""
sql_query(q)
# Out:
#                                                Major  Percentage_Women
# 0                              AEROSPACE ENGINEERING        106.362067
# 1                                       FOOD SCIENCE        655.262554
# 2        MATERIALS ENGINEERING AND MATERIALS SCIENCE        113.063816
# 3             GEOLOGICAL AND GEOPHYSICAL ENGINEERING        529.305556
# 4  NUCLEAR, INDUSTRIAL RADIOLOGY, AND BIOLOGICAL ...        270.652174

# %%
q = """SELECT Women, men, Major, Total from recent_grads
        where Major == 'FOOD SCIENCE'


"""
sql_query(q)
# Out:
#    Women    Men         Major  Total
# 0  28576  99743  FOOD SCIENCE   4361

# %%
28576+99743
# Out:
# 128319

# %%
q =  """Select women + men, total
        from recent_grads

"""
sql_query(q)
# Out:
#      women + men  Total
# 0           2339   2339
# 1            756    756
# 2            856    856
# 3           1258   1258
# 4          32260  32260
# ..           ...    ...
# 168         8409   8409
# 169         2854   2854
# 170         2838   2838
# 171         4626   4626
# 172         1098   1098
#
# [173 rows x 2 columns]

# %%
q = """Select Women, men, total from recent_grads
        where Major == 'FOOD SCIENCE'


"""
sql_query(q)
# Out:
#    Women    Men  Total
# 0  28576  99743   4361

# %%
q =  """Select women + men, total
        from recent_grads
        where Major == 'FOOD SCIENCE'

"""
sql_query(q)
# Out:
#    women + men  Total
# 0       128319   4361

# %%
q = """SELECT Major, (cast(Women as float)/(men + women))*100 percentage_women from recent_grads

"""
sql_query(q)
# Out:
#                                          Major  percentage_women
# 0                        PETROLEUM ENGINEERING         12.056434
# 1               MINING AND MINERAL ENGINEERING         10.185185
# 2                    METALLURGICAL ENGINEERING         15.303738
# 3    NAVAL ARCHITECTURE AND MARINE ENGINEERING         10.731320
# 4                         CHEMICAL ENGINEERING         34.163050
# ..                                         ...               ...
# 168                                    ZOOLOGY         63.729338
# 169                     EDUCATIONAL PSYCHOLOGY         81.709881
# 170                        CLINICAL PSYCHOLOGY         79.985906
# 171                      COUNSELING PSYCHOLOGY         79.874622
# 172                            LIBRARY SCIENCE         87.795993
#
# [173 rows x 2 columns]

# %%
q = """SELECT Major, (cast(Women as float)/(men + women))*100 percentage_women from recent_grads
        order by Percentage_Women DESC
"""
sql_query(q)
# Out:
#                                          Major  percentage_women
# 0                  ANTHROPOLOGY AND ARCHEOLOGY         96.895368
# 1                    EARLY CHILDHOOD EDUCATION         96.799812
# 2             MATHEMATICS AND COMPUTER SCIENCE         92.780725
# 3                         ELEMENTARY EDUCATION         92.374548
# 4                              ANIMAL SCIENCES         91.093257
# ..                                         ...               ...
# 168  NAVAL ARCHITECTURE AND MARINE ENGINEERING         10.731320
# 169             MINING AND MINERAL ENGINEERING         10.185185
# 170                   ENGINEERING TECHNOLOGIES          9.071251
# 171                          MOLECULAR BIOLOGY          7.745303
# 172     MISCELLANEOUS ENGINEERING TECHNOLOGIES          0.000000
#
# [173 rows x 2 columns]

# %%
q = """SELECT Major, (cast(Women as float)/(men + women))*100 percentage_women from recent_grads
        order by Percentage_Women DESC limit 5
  
"""
sql_query(q)
# Out:
#                               Major  percentage_women
# 0       ANTHROPOLOGY AND ARCHEOLOGY         96.895368
# 1         EARLY CHILDHOOD EDUCATION         96.799812
# 2  MATHEMATICS AND COMPUTER SCIENCE         92.780725
# 3              ELEMENTARY EDUCATION         92.374548
# 4                   ANIMAL SCIENCES         91.093257

# %%
q = """select Major, Major_category, ShareWomen, Men, Women
        from recent_grads
        where Women > Men

"""
sql_query(q)
# Out:
#                                  Major            Major_category  ShareWomen  \
# 0                    ACTUARIAL SCIENCE                  Business    0.535714
# 1                     COMPUTER SCIENCE   Computers & Mathematics    0.578766
# 2            ENVIRONMENTAL ENGINEERING               Engineering    0.558548
# 3                              NURSING                    Health    0.896019
# 4   INDUSTRIAL PRODUCTION TECHNOLOGIES               Engineering    0.750473
# ..                                 ...                       ...         ...
# 92                             ZOOLOGY    Biology & Life Science    0.637293
# 93              EDUCATIONAL PSYCHOLOGY  Psychology & Social Work    0.817099
# 94                 CLINICAL PSYCHOLOGY  Psychology & Social Work    0.799859
# 95               COUNSELING PSYCHOLOGY  Psychology & Social Work    0.798746
# 96                     LIBRARY SCIENCE                 Education    0.877960
#
#       Men   Women
# 0     832     960
# ...

# %%
q = """select Major, Major_category, Unemployment_rate
        from recent_grads
        where Major_category in ("Engineering", "Physical Sciences")
"""
sql_query(q)
# Out:
#                                                 Major     Major_category  \
# 0                               PETROLEUM ENGINEERING        Engineering
# 1                      MINING AND MINERAL ENGINEERING        Engineering
# 2                           METALLURGICAL ENGINEERING        Engineering
# 3           NAVAL ARCHITECTURE AND MARINE ENGINEERING        Engineering
# 4                                CHEMICAL ENGINEERING        Engineering
# 5                                 NUCLEAR ENGINEERING        Engineering
# 6                          ASTRONOMY AND ASTROPHYSICS  Physical Sciences
# 7                              MECHANICAL ENGINEERING        Engineering
# 8                              ELECTRICAL ENGINEERING        Engineering
# 9                                COMPUTER ENGINEERING        Engineering
# 10                              AEROSPACE ENGINEERING        Engineering
# 11                             BIOMEDICAL ENGINEERING        Engineering
# ...

# %%
q = """select Major, Major_category, Unemployment_rate, ShareWomen
        from recent_grads
        where Major_category in ("Engineering", "Physical Sciences")
        and 
        ShareWomen Between 0.5 and 0.8


"""
sql_query(q)
# Out:
#                                    Major     Major_category  \
# 0              ENVIRONMENTAL ENGINEERING        Engineering
# 1     INDUSTRIAL PRODUCTION TECHNOLOGIES        Engineering
# 2                           OCEANOGRAPHY  Physical Sciences
# 3                              CHEMISTRY  Physical Sciences
# 4  MULTI-DISCIPLINARY OR GENERAL SCIENCE  Physical Sciences
#
#    Unemployment_rate  ShareWomen
# 0           0.093589    0.558548
# 1           0.028308    0.750473
# 2           0.056995    0.688999
# 3           0.053972    0.505141
# 4           0.055807    0.669999

# %%
q = """SELECT major, Major_category, Unemployment_rate, ShareWomen
        from recent_grads
        where Major_category IN ("Engineering", "Physical Sciences")
        and 
        ShareWomen Between 0.5 and 0.8
        """

sql_query(q)
# Out:
#                                    Major     Major_category  \
# 0              ENVIRONMENTAL ENGINEERING        Engineering
# 1     INDUSTRIAL PRODUCTION TECHNOLOGIES        Engineering
# 2                           OCEANOGRAPHY  Physical Sciences
# 3                              CHEMISTRY  Physical Sciences
# 4  MULTI-DISCIPLINARY OR GENERAL SCIENCE  Physical Sciences
#
#    Unemployment_rate  ShareWomen
# 0           0.093589    0.558548
# 1           0.028308    0.750473
# 2           0.056995    0.688999
# 3           0.053972    0.505141
# 4           0.055807    0.669999

# %%
q = """select Major, Major_category, Unemployment_rate
        from recent_grads
        where Major_category == "Engineering" or Major_category == "Physical Sciences"
        
"""
sql_query(q)
# Out:
#                                                 Major     Major_category  \
# 0                               PETROLEUM ENGINEERING        Engineering
# 1                      MINING AND MINERAL ENGINEERING        Engineering
# 2                           METALLURGICAL ENGINEERING        Engineering
# 3           NAVAL ARCHITECTURE AND MARINE ENGINEERING        Engineering
# 4                                CHEMICAL ENGINEERING        Engineering
# 5                                 NUCLEAR ENGINEERING        Engineering
# 6                          ASTRONOMY AND ASTROPHYSICS  Physical Sciences
# 7                              MECHANICAL ENGINEERING        Engineering
# 8                              ELECTRICAL ENGINEERING        Engineering
# 9                                COMPUTER ENGINEERING        Engineering
# 10                              AEROSPACE ENGINEERING        Engineering
# 11                             BIOMEDICAL ENGINEERING        Engineering
# ...

# %%
# Major , Unemployment_rate --> Top 3
q = """select Major , Unemployment_rate
    from recent_grads
    order by Unemployment_rate DESC limit 3

"""
sql_query(q)
# Out:
#                                         Major  Unemployment_rate
# 0                         NUCLEAR ENGINEERING           0.177226
# 1                       PUBLIC ADMINISTRATION           0.159491
# 2  COMPUTER NETWORKING AND TELECOMMUNICATIONS           0.151850

# %%
q = """select Major, Major_category, ShareWomen from recent_grads
        where SahreWomen > avg(ShareWomen)
"""
sql_query(q)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\io\sql.py:2020, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2019 try:
# -> 2020     cur.execute(*args, **kwargs)
#    2021     return cur
#
# OperationalError: no such column: SahreWomen
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Input In [101], in <cell line: 4>()
#       1 q = """select Major, Major_category, ShareWomen from recent_grads
#       2         where SahreWomen > avg(ShareWomen)
#       3 """
# ----> 4 sql_query(q)
#
# Input In [45], in sql_query(q)
#       2 def sql_query(q):
# ----> 3     return pd.read_sql_query(q, conn)
#
# ...

# %%
q = """select avg(ShareWomen) from recent_grads"""
sql_query(q)
# Out:
#    avg(ShareWomen)
# 0          0.52255

# %%
q = """select Major, Major_category, ShareWomen
        from recent_grads
        where ShareWomen > (select avg(ShareWomen) from recent_grads)
        order by ShareWomen DESC
        limit 10
"""
sql_query(q)
# Out:
#                                        Major                   Major_category  \
# 0                ANTHROPOLOGY AND ARCHEOLOGY        Humanities & Liberal Arts
# 1                  EARLY CHILDHOOD EDUCATION                        Education
# 2           MATHEMATICS AND COMPUTER SCIENCE          Computers & Mathematics
# 3                       ELEMENTARY EDUCATION                        Education
# 4                            ANIMAL SCIENCES  Agriculture & Natural Resources
# 5                                 PHYSIOLOGY           Biology & Life Science
# 6                   MISCELLANEOUS PSYCHOLOGY         Psychology & Social Work
# 7  HUMAN SERVICES AND COMMUNITY ORGANIZATION         Psychology & Social Work
# 8                                    NURSING                           Health
# 9                                GEOSCIENCES                Physical Sciences
#
#    ShareWomen
# 0    0.968954
# 1    0.967998
# 2    0.927807
# 3    0.923745
# 4    0.910933
# 5    0.906677
# ...

# %%
q = "select major from recent_grads"
sql_query(q)
# Out:
#                                          Major
# 0                        PETROLEUM ENGINEERING
# 1               MINING AND MINERAL ENGINEERING
# 2                    METALLURGICAL ENGINEERING
# 3    NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4                         CHEMICAL ENGINEERING
# ..                                         ...
# 168                                    ZOOLOGY
# 169                     EDUCATIONAL PSYCHOLOGY
# 170                        CLINICAL PSYCHOLOGY
# 171                      COUNSELING PSYCHOLOGY
# 172                            LIBRARY SCIENCE
#
# [173 rows x 1 columns]

# %%
q = "select count(major) from recent_grads"
sql_query(q)
# Out:
#    count(major)
# 0           173

# %%
q = """select count(major) No_of_fields_Avg_SH,
       (select count(major) from recent_grads) Total_of_fields 
        from recent_grads
        where ShareWomen > (select avg(ShareWomen) from recent_grads)
        """

sql_query(q)
# Out:
#    No_of_fields_Avg_SH  Total_of_fields
# 0                   91              173

# %%
q = """select count(major) No_of_fields_Avg_SH, 
        (173) Total_of_fields
       from recent_grads
       where ShareWomen > (0.522)"""
sql_query(q)
# Out:
#    No_of_fields_Avg_SH  Total_of_fields
# 0                   91              173

# %%
q = """select major from recent_grads

"""
sql_query(q)
# Out:
#                                          Major
# 0                        PETROLEUM ENGINEERING
# 1               MINING AND MINERAL ENGINEERING
# 2                    METALLURGICAL ENGINEERING
# 3    NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4                         CHEMICAL ENGINEERING
# ..                                         ...
# 168                                    ZOOLOGY
# 169                     EDUCATIONAL PSYCHOLOGY
# 170                        CLINICAL PSYCHOLOGY
# 171                      COUNSELING PSYCHOLOGY
# 172                            LIBRARY SCIENCE
#
# [173 rows x 1 columns]

# %%
q = """select cast(count(major) as float)/(select count(major) from recent_grads)*100
        "percentage fields greater than Avg SahereWomen"
        from recent_grads
        where ShareWomen > (select avg(ShareWomen) from recent_grads)

"""
sql_query(q)
# Out:
#    percentage fields greater than Avg SahereWomen
# 0                                       52.601156

# %%
q = """select cast(count(major_category) as float)/(select count(major_category) from recent_grads)*100
        Percentage_filed_of_Majorcategory_greaterthan_Avg_Share
        from recent_grads
        where ShareWomen > (select avg(ShareWomen) from recent_grads)
    
"""
sql_query(q)
# Out:
#    Percentage_filed_of_Majorcategory_greaterthan_Avg_Share
# 0                                          52.601156

# %%
q = """select Major_category, sum(Men + Women) Total
        from recent_grads
        group by 1
        order by 2
"""
sql_query(q)
# Out:
#                          Major_category    Total
# 0                   Law & Public Policy    15962
# 1                     Interdisciplinary    19879
# 2   Industrial Arts & Consumer Services    71867
# 3               Computers & Mathematics   122222
# 4           Communications & Journalism   134970
# 5                                  Arts   227250
# 6                              Business   287284
# 7                                Health   406656
# 8                     Physical Sciences   429875
# 9       Agriculture & Natural Resources   447687
# 10            Humanities & Liberal Arts   509581
# 11                          Engineering   518695
# 12             Psychology & Social Work   740509
# 13                            Education   870670
# 14                       Social Science   966973
# 15               Biology & Life Science  1005935

# %%
q = """select Major_category, sum(Men + Women) Total
        from recent_grads
        group by Major_category
        order by Total
"""
sql_query(q)
# Out:
#                          Major_category    Total
# 0                   Law & Public Policy    15962
# 1                     Interdisciplinary    19879
# 2   Industrial Arts & Consumer Services    71867
# 3               Computers & Mathematics   122222
# 4           Communications & Journalism   134970
# 5                                  Arts   227250
# 6                              Business   287284
# 7                                Health   406656
# 8                     Physical Sciences   429875
# 9       Agriculture & Natural Resources   447687
# 10            Humanities & Liberal Arts   509581
# 11                          Engineering   518695
# 12             Psychology & Social Work   740509
# 13                            Education   870670
# 14                       Social Science   966973
# 15               Biology & Life Science  1005935

# %%
q = """ select Major_category, sum(Men + Women) Total from recent_grads
        group by 1
        having Total > 10000
        Order by 2"""

sql_query(q)
# Out:
#                         Major_category   Total
# 0                    Interdisciplinary   19879
# 1  Industrial Arts & Consumer Services   71867
# 2              Computers & Mathematics  122222
# 3          Communications & Journalism  134970
# 4                               Health  406656
# 5                       Social Science  966973

# %%
q = """select Major_category, Women, Women+Men Total 
        from recent_grads
        where Major_category = 'Engineering'

"""
sql_query(q)
# Out:
#    Major_category  Women  Total
# 0     Engineering    282   2339
# 1     Engineering     77    756
# 2     Engineering    131    856
# 3     Engineering    135   1258
# 4     Engineering  11021  32260
# 5     Engineering    373   2573
# 6     Engineering   2105  15058
# 7     Engineering   6548  14955
# 8     Engineering   8284  41542
# 9     Engineering  16016  81527
# 10    Engineering  10907  91227
# 11    Engineering   1330   4279
# 12    Engineering    795   4321
# 13    Engineering   2863   8925
# 14    Engineering   6515  18968
# 15    Engineering  15469  61152
# 16    Engineering    990   2825
# 17    Engineering    973   2993
# 18    Engineering   3384  11565
# 19    Engineering  12072  53153
# 20    Engineering   1735   9133
# 21    Engineering   3339   5978
# 22    Engineering   1678  18498
# 23    Engineering   3811  11732
# 24    Engineering   1588   2116
# 25    Engineering    506   2906
# 26    Engineering   4582  14240
# 27    Engineering      0    124
# ...

# %%
q = """select Major_category, Women, Women+Men Total 
        from recent_grads
        group by 1
        having Major_category == "Engineering"

"""
sql_query(q)
# Out:
#   Major_category  Women  Total
# 0    Engineering    282   2339

# %%
q = """select Major_category, cast(sum(women) as float)/sum(women + Men)*100 Womem_grads_per
       from recent_grads
       where Major_category == 'Physical Sciences'

"""
sql_query(q)
# Out:
#       Major_category  Womem_grads_per
# 0  Physical Sciences        56.992382

# %%
q = """select Major_category, cast(sum(women) as float)/sum(women + Men)*100 Womem_grads_per
       from recent_grads
       group by 1
       order by 2

"""
sql_query(q)
# Out:
#                          Major_category  Womem_grads_per
# 0                           Engineering        22.759232
# 1                   Law & Public Policy        34.319008
# 2                              Business        38.417385
# 3                        Social Science        47.945082
# 4                     Interdisciplinary        49.539715
# 5               Computers & Mathematics        51.217457
# 6   Industrial Arts & Consumer Services        51.239094
# 7       Agriculture & Natural Resources        55.800593
# 8                     Physical Sciences        56.992382
# 9                Biology & Life Science        57.472103
# 10                                 Arts        61.812541
# 11             Psychology & Social Work        68.150691
# 12            Humanities & Liberal Arts        68.612448
# 13                            Education        70.400726
# 14          Communications & Journalism        72.814700
# ...

# %%
q = """select Major_category, cast(sum(women) as float)/sum(women + Men)*100 Womem_grads_per
       from recent_grads
       group by 1
       order by 2 DESC limit 3

"""
sql_query(q)
# Out:
#                 Major_category  Womem_grads_per
# 0                       Health        76.729718
# 1  Communications & Journalism        72.814700
# 2                    Education        70.400726

# %%
# cal Men Per
q = """select Distinct(Major_category), cast(sum(Men) as float)/sum(Women+Men)*100
        from recent_grads
        group by 1
        order by 2

"""
sql_query(q)
# Out:
#                          Major_category  \
# 0                                Health
# 1           Communications & Journalism
# 2                             Education
# 3             Humanities & Liberal Arts
# 4              Psychology & Social Work
# 5                                  Arts
# 6                Biology & Life Science
# 7                     Physical Sciences
# 8       Agriculture & Natural Resources
# 9   Industrial Arts & Consumer Services
# 10              Computers & Mathematics
# 11                    Interdisciplinary
# 12                       Social Science
# 13                             Business
# 14                  Law & Public Policy
# 15                          Engineering
#
#     cast(sum(Men) as float)/sum(Women+Men)*100
# 0                                    23.270282
# 1                                    27.185300
# 2                                    29.599274
# 3                                    31.387552
# ...

# %%
# Top 3 per
q = """select Distinct(Major_category), cast(sum(Men) as float)/sum(Women+Men)*100
        Men_Grads_Pct
        from recent_grads
        group by 1
        order by 2 DESC limit 3
        

"""
sql_query(q)
# Out:
#         Major_category  Men_Grads_Pct
# 0          Engineering      77.240768
# 1  Law & Public Policy      65.680992
# 2             Business      61.582615

# %%
q = """select Distinct(Major_category), sum(men+Women) Total 
        from recent_grads
        group by 1
        order by 2 DESC limit 3
        
"""
sql_query(q)
# Out:
#            Major_category    Total
# 0  Biology & Life Science  1005935
# 1          Social Science   966973
# 2               Education   870670

# %%
q = """select Major_category from recent_grads
        group by 1

"""
sql_query(q)
# Out:
#                          Major_category
# 0       Agriculture & Natural Resources
# 1                                  Arts
# 2                Biology & Life Science
# 3                              Business
# 4           Communications & Journalism
# 5               Computers & Mathematics
# 6                             Education
# 7                           Engineering
# 8                                Health
# 9             Humanities & Liberal Arts
# 10  Industrial Arts & Consumer Services
# 11                    Interdisciplinary
# 12                  Law & Public Policy
# 13                    Physical Sciences
# 14             Psychology & Social Work
# 15                       Social Science

# %%
q = """select Major_category, sum(Women+Men) Total from recent_grads
        group by 1
        order by sum(Women+Men) DESC limit 3

"""
sql_query(q)
# Out:
#            Major_category    Total
# 0  Biology & Life Science  1005935
# 1          Social Science   966973
# 2               Education   870670

# %%
q = """select Major, Major_category from recent_grads
        where Major_category IN ("Biology & Life Science","Social Science","Education")"""

sql_query(q)
# Out:
#                                           Major          Major_category
# 0                                     ECONOMICS          Social Science
# 1                                  PHARMACOLOGY  Biology & Life Science
# 2           COGNITIVE SCIENCE AND BIOPSYCHOLOGY  Biology & Life Science
# 3                     SCHOOL STUDENT COUNSELING               Education
# 4                       INTERNATIONAL RELATIONS          Social Science
# 5                             MOLECULAR BIOLOGY  Biology & Life Science
# 6                                      GENETICS  Biology & Life Science
# 7                 MISCELLANEOUS SOCIAL SCIENCES          Social Science
# 8              POLITICAL SCIENCE AND GOVERNMENT          Social Science
# 9                                     GEOGRAPHY          Social Science
# 10                                 MICROBIOLOGY  Biology & Life Science
# 11                         BIOCHEMICAL SCIENCES  Biology & Life Science
# ...

# %%
q = """select Major, Major_category from recent_grads
        where Major_category IN
        (select Major_category from recent_grads
        group by 1
        order by sum(men+women) DESC
        limit 3)

"""
sql_query(q)
# Out:
#                                           Major          Major_category
# 0                                     ECONOMICS          Social Science
# 1                                  PHARMACOLOGY  Biology & Life Science
# 2           COGNITIVE SCIENCE AND BIOPSYCHOLOGY  Biology & Life Science
# 3                     SCHOOL STUDENT COUNSELING               Education
# 4                       INTERNATIONAL RELATIONS          Social Science
# 5                             MOLECULAR BIOLOGY  Biology & Life Science
# 6                                      GENETICS  Biology & Life Science
# 7                 MISCELLANEOUS SOCIAL SCIENCES          Social Science
# 8              POLITICAL SCIENCE AND GOVERNMENT          Social Science
# 9                                     GEOGRAPHY          Social Science
# 10                                 MICROBIOLOGY  Biology & Life Science
# 11                         BIOCHEMICAL SCIENCES  Biology & Life Science
# ...
